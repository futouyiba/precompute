# %%
# visualize ""D:\fishinggame\ExportedData\Fishing_1006001_Dense_20260107_154037\Fishing_1006001_Global.npy"":（path is already in this workspace）
# 3d visualization, y is up, x is right, z is forward
# use different colors for bitmask, bit mask doc: ./VoxelMapDataFormat.md
